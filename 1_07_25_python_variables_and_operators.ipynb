# %%
a=100

# %%
A='SUBMISSIONS'

# %%
a1=23

# %%
Yourname=True,

# %%
yournamesurname='er',

# %%
your name='er', #no space in variable declaration
# Out:
#   Cell In[47], line 1
#     your name='er', #no space in variable declaration
#          ^
# SyntaxError: invalid syntax

# %%
suoermarket123=11

# %%
1_christmas=78, # donot start with number in variable declartion
# Out:
#   Cell In[46], line 1
#     1_christmas=78,
#      ^
# SyntaxError: invalid decimal literal

# %%
_christmas=1212,

# %%
__christmas=12134

# %%
@christmas=12, #no @ in variable declartion
# Out:
#   Cell In[44], line 1
#     @christmas=12,
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
@y=11,
# Out:
#   Cell In[29], line 1
#     @y=11,
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
y@x=90,
# Out:
#   Cell In[28], line 1
#     y@x=90,
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
amount=100,

# %%
AMOUNT=400,

# %%
Amount=220,

# %%
AmOunt=900,

# %%
CountWord=230,

# %%
Count_Word=450,

# %%
currency%=100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 currency%=100
#
# NameError: name 'currency' is not defined

# %%
__=100

# %%
import keyword 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print=100

# %%
a=10

# %%
print('Teja',10,a)
# Out:
# Teja 10 10

# %%
hello='hell0'

# %%
print("Hello Satya")
# Out:
# Hello Satya

# %%
a='Hello'
b='Teja'
a+b
# Out:
# 'HelloTeja'

# %%
a=10
b=20
c=40
print('this is a : ',a)
print('this is a : {} '.format(a))
print('this is b :{} '.format(b))
print('this is b :{} b :{}'.format(a,b))

print('this is a:{1},b:{2},c:{2}'.format(a,b,c))
# Out:
# this is a :  10
# this is a : 10
# this is b :20
# this is a :10 b :20
# this is a:20,b:40,c:40

# %% [markdown]
# ### Arthimetic Operators(+,-,*,/,%)--(basic Maths operators) and (**,//)
#    ##### ---(**=power of(EX=2power2=4)
#    ##### ---(//=to removee float value(EX=5/2=2.5 result but it will give 2)

# %%
a=10
b=20
print(a+b)
a-b
b*a
b%a
b/a
a**b
print(a//b)
a**b
a//b
# Out:
# 30
# 0
# 0

# %%
a=10
b=20
print(f"addition : {a+b}")
print(f"subtraction : {a-b}")
print(f"division : {a/b}")
print(f"multiplication : {a*b}")
# Out:
# addition : 30
# subtraction : -10
# division : 0.5
# multiplication : 200

# %%
a=9
b=10
e=a+b
d=a/b
print('the value of a d:{} and e:{} is',(d,e))
# Out:
# the value of a d:{} and e:{} is (0.9, 19)

# %%
print ('the value of a :{} and b :{} is {}' .format(a,b,a/b))
# Out:
# the value of a :9 and b :10 is 0.9

# %%
a=10
b=20
c=25
print('this is a:{0},b:{1},c:{2},{3}'.format(a,b,c,a<b))
# Out:
# this is a10,b:20,c:25,True

# %%
a=10,12,15

# %%
a=13
b='teja'
c=9.5
d=5+2j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'complex'>

# %%
a,b,c=1,2,3

# %%
a,c,b
# Out:
# (1, 3, 2)

# %%
a=str(a)
a
# Out:
# '10'

# %% [markdown]
# # Type Conversion

# %%
a=10
type(a)
# Out:
# int

# %%
#type conversion
a=10
a=str(a)
a
# Out:
# '10'

# %%
a='teja'
a=int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 a='teja'
# ----> 2 a=int(a)
#
# ValueError: invalid literal for int() with base 10: 'teja'

# %% [markdown]
# ## Swapping Two Numbers

# %%
a=20
b=10
temp=a
a=b
b=temp
a,b
# Out:
# (10, 20)

# %% [markdown]
# ### Swapping Numbers Method2

# %%
#hw
a=2000
b=1000
a=a-b
b=a+b
a,b
# Out:
# (1000, 2000)

# %% [markdown]
# # Relational operators (>,<,>=,,<=,==.!=)

# %%
a=9
b=7
print(f"{a} is greater than {b} : {a>b}")
print(f"{b} is greater than {a} : {a<b}")
print('{0} is greater than {1} : {2}  '.format(a,b,a>b))
print('{1} is greater than {0} : {2}  '.format(a,b,a<b))
# Out:
# 9 is greater than 7 : True
# 7 is greater than 9 : False
# 9 is greater than 7 : 16
# 7 is greater than 9 : False

# %%
name = "Tejaswa"
a=10
print(f"Hello {name}! {a}")
# Out:
# Hello Tejaswa! 10

# %%
print("{} is my name".format("Tejaswa"))
# Out:
# Tejaswa is my name

# %%
a=10
b=14
c=30
d=18
f=14
print(a>b)
# Out:
# False

# %%
print(a<b)
# Out:
# True

# %%
print(f>=b)
# Out:
# True

# %%
print(f<=b)
# Out:
# True

# %%
print(f==b)
# Out:
# True

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %% [markdown]
# ### logical operators-- Logical AND (and)
# Used for: True, False, or truthy/falsy values (like 0, 1, [], "text" etc.)
#
# Behavior: Checks if both values are logically True
#
# Stops early if the first value is False (short-circuiting)
#
# Does not convert to binary

# %%
a=True
b=0
a and b
# Out:
# 0

# %%
a or b
# Out:
# True

# %%
not b
# Out:
# True

# %%
a=True
b=False
print('a:{0} and b:{1} : {2}' .format(a,b,a and b))
# Out:
# a:True and b:False : False

# %%
a=18
b=9
a and b
# Out:
# 9

# %%
a=18
b=9
a or b
# Out:
# 18

# %%
a=False
b='Teja'
a and b
# Out:
# False

# %%
a='Teja'
b='lav'
a and b
# Out:
# 'lav'

# %%
a=True 
b=False
b and a
# Out:
# False

# %%
a=0
b=False
a and b
# Out:
# 0

# %%
a=False
b=False
print(f" {a} and {b} : {a and b}")
# Out:
#  False and False : False

# %%
a=1
b='teja'
print('{0} or {1} is : {2}'.format(a,b,a or b))
# Out:
# 1 or teja is : 1

# %% [markdown]
# ### Bitwise operator --
# Bitwise AND (&)
# Used for: integers or booleans only
#
# Behavior: Converts numbers into binary and compares each bit
#
# Always evaluates both sides
#
# Returns a number (bitwise result)

# %%
a=7
b=8
a&b
# Out:
# 0

# %% [markdown]
# bin(20)

# %%
a=7
b=8
a|b
# Out:
# 15

# %%
a=18
b=9
a & b
# Out:
# 0

# %% [markdown]
# ### Difference between logical(and) and bitwise(&)

# %%
a = False  # 110 in binary
b = 3   # 011 in binary

print(a and b)   # Output: 3 (logical check, both are truthy)
print(a & b)     # Output: 2 (bitwise AND → 110 & 011 = 010)
# Out:
# False
# 0

# %% [markdown]
# ## XOR operator (^) (Bitwise operator) (if same bits its zero and if its different bits its 1)

# %%
a=16
b=20
a^b
# Out:
# 4

# %%
a=1000
b=2000
a^b
# Out:
# 1080

# %%
bin(1000)
# Out:
# '0b1111101000'

# %%
a=20
b=10
{
    (a<4)
}
# Out:
# {False}

# %%
bin(16)
# Out:
# '0b10000'

# %% [markdown]
# ## Bitwise Not(~) N=~12 formula = -(N+1)

# %%
n=~12
n
# Out:
# -13

# %%
~-17
# Out:
# 16

# %%
~5
# Out:
# -6

# %% [markdown]
# ## Right Shift and left shift (Bitwise Operators)

# %%
12>>3
# Out:
# 1

# %%
10>>2
# Out:
# 2

# %%
12<<3
# Out:
# 96

# %%
15<<2
# Out:
# 60

# %%
16<<2
# Out:
# 64

# %% [markdown]
# # identity operators (Is and Is not)
# #### --(From 0 to 256 in positive numbers they will be stored in same adress)
# #### --(in negative numbers upto -5 they will be stored in same adrress)
# ##### ---after this ranges computer allocate different adress locations in the memory

# %%
a=256
b=256
a is b
# Out:
# True

# %% [markdown]
# a=257
# b=257
# a is b  #range of adresses

# %%
a=-5
b=-5
a is b #range of adresses
# Out:
# True

# %%
a=-20
print('id = ' ,id(a))
b=-20
print('id = ' ,id(b))
# Out:
# id =  2876560883888
# id =  2876560885616

# %%
a=-2
print('id = ' ,id(a))
b=-2
print('id = ' ,id(b)) # same adresses wil be present upto -5 in in identity operators (-range)
# Out:
# id =  140709381911368
# id =  140709381911368

# %%
a=30
print('id = ' ,id(a))
b=30
print('id = ' ,id(b)) #in positive side upto 256
# Out:
# id =  140709381912392
# id =  140709381912392

# %% [markdown]
# ## membership operator -- (In,Not In) checks the existence of value in others

# %%
a='Teja'
b='Te'
a not in b
# Out:
# True

# %%
a='Teja'
b='Tej'
b in a #if in
# Out:
# True

# %%
a='python is fun'
b='python'
a.startswith(b)
# Out:
# True

# %%
a='99'
b='9'
b in a
# Out:
# True

# %% [markdown]
# #### Indexing (positive indexing(o to n ) , Negative Indexing(-1 to n) -- From Backwards)
# #### And
# #### Slicing

# %%
a='robin'
a[0]+a[1]+a[4]
# Out:
# 'ron'

# %%
a[-1]
# Out:
# 'n'

# %%
a='robin Sharma is my name'
a[0]+a[22]+a[14]
# Out:
# 'res'

# %%
a[0:5]
# Out:
# 'rbn'

# %%
a[0:5:2] #Slicing
# Out:
# 'rbn'

# %%
a[1:12:2] #start,End,Skip skip slicing
# Out:
# 'oi hra'

# %%
a="5"
a[0]
# Out:
# '5'

# %%
a=(a+1j)
str(a)
a[0]
# a complex value converting into string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 a=(a+1j)
#       2 str(a)
# ----> 3 a[0]
#
# TypeError: 'complex' object is not subscriptable

# %% [markdown]
# ## slicing (start:end:skip)

# %%
a='Manish'

# %%
a[ :4:2]
# Out:
# 'Mn'

# %%
a='Christmas is around the corner'
a[-1]
# Out:
# 'r'

# %%
a[::2]
# Out:
# 'Crsmsi rudtecre'

# %%
a[:5]
# Out:
# 'Chris'

# %%
a[5:]
# Out:
# 'tmas is around the corner'

# %%
a[-7:-3:1]
# Out:
# ' cor'

# %%
a[::-1]
# Out:
# 'renroc eht dnuora si samtsirhC'

# %%
a[-7:23:1]
# Out:
# ''

# %%
a[23:-7:-1]
# Out:
# ''

# %%
a[-7:-3:-1]
# Out:
# ''

# %% [markdown]
# ## inbuilt functions(len,count,upper,lower,capitralize,
# ## title,index,find,replace,strip,isdigit,isalpha,isalnum)

# %%
a[0]='s'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 a[0]='s'
#
# TypeError: 'str' object does not support item assignment

# %%
a='teja'

# %%
len(a) #number of words in a string(start from 1)
# Out:
# 4

# %%
a='teja' ' ' 'sk'
a.count('z')
#counting substring
# Out:
# 0

# %%
strr="Python is an amazing language"  
strr.index('y')
# Out:
# 1

# %%
a.lower() #makes all letters in string lowercase
# Out:
# 'teja'

# %%
a.upper() # makes all letters in the string uppercase
# Out:
# 'TEJA'

# %%
a.capitalize()
#making first letter capital only after spaces will not give capital
# Out:
# 'Teja sk'

# %%
a.title() #makes 1st word capital after spaces also 1st word will be capital
# Out:
# 'Teja Sk'

# %%
a='teja'

# %%
a.find('tek')
#finds the index. if not found gives -1
# Out:
# -1

# %%
a.find(a) #gives zero because the a given substring will start from 0 a=teja
# Out:
# 0

# %%
a='teja sw'

# %%
a.index('a')
# Out:
# 3

# %%
a.index('a') #finds the substring index number starting
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 a.index('a')
#
# AttributeError: 'dict' object has no attribute 'index'

# %%
a.index('swa') # difference between find give -1 if the given substring is not found whereas index give valueerror 
#if not found in the given string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 a.index('swa')
#
# ValueError: substring not found

# %%
a.replace()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 a.replace()
#
# TypeError: replace() takes at least 2 positional arguments (0 given)

# %%
a='velex'

# %%
a.replace('x','j')
#replace(replacing word , replaced word)
# Out:
# 'velej'

# %%
a='velex teja Rohan'

# %%
a.split() #splits a single string into two strings
# Out:
# ['velex', 'teja', 'Rohan']

# %%
a='tejswa'

# %%
a.strip('tej')
#removes the word that passed in the arguments place
# Out:
# 'swa'

# %%
a='teja'
b=9

# %%
a.isdigit() # isdigit only checks the given string contains all number or not
# Out:
# False

# %%
b.isdigit()
# Out:
# True

# %%
a='teja'
b='9'

# %%
a.isalpha() #isalpha only checks the given string contains all alphabets or not
# Out:
# True

# %%
b.isalpha()
# Out:
# False

# %%
a='teja1245'
b='sadhu tejaswa9'

# %%
a.isalnum() #isalnum gives true if any of the alphabet or number is present
# Out:
# True

# %%
b.isalnum() #if there are spaces in between the strings it will not give true
# Out:
# False

# %% [markdown]
# ## list(datatype)

# %%
a = [2.0,9,'teja',9+2j,['sadhu',9],80]
type(a)
#heterogeneous,ordered(indexing and slicing),nested,mutable(can be changed)
# check duplication and hashability
# Out:
# list

# %%
a[4][1]
# Out:
# 9

# %%
a=[10,90,80]
min(a)
# Out:
# 10

# %%
a #ordered (follows how the input given ouput will also like that)
# Out:
# [2.0, 9, 'teja', (9+2j), ['sadhu', 9], 80]

# %%
a[0]
#a[3] #indexing
# Out:
# 2.0

# %%
a[:]#slicing
# Out:
# [2.0, 9, 'teja', (9+2j), ['sadhu', 9], 80]

# %%
a[0:4:2]#slicing with skip
# Out:
# [2.0, 'teja']

# %%
a[2] = "sadhu tejaswa"

# %%
a
# Out:
# [2.0, 9, 'sadhu tejaswa', (9+2j), ['sadhu', 9], 80]

# %%
a[-2]
# Out:
# ['sadhu', 9]

# %%
a[4][1] #Acessing Nested Elements
# Out:
# 9

# %%
a[-2][-1]
# Out:
# 9

# %%
a=[1,2,3,4,5]
len(a)
# Out:
# 5

# %%
a=[1,5,78]
a.append('teja')
a #append adds one element at a time
# Out:
# [1, 5, 78, 'teja']

# %%
a.extend([9,8,56,'sadhu'])
a #adds bunch of elements at a time
# Out:
# [1, 5, 78, 'teja', 9, 8, 56, 'sadhu']

# %%
a.append('139')
a
# Out:
# [1, 5, 78, 'teja', 's', 'a', 'd', 'h', 'u', '139']

# %%
a.extend('18114')
a
# Out:
# [1, 2, 3, 4, 5, '1', '8', '1', '1', '4']

# %%
import copy
a=[12,13,14,[11,10]]
b=copy.copy(a)
a[-1][-1]='satya'
print(a)
print(b) # in copy changes made in a by using indexing will reflect on b
id(b)
# Out:
# [12, 13, 14, [11, 'satya']]
# [12, 13, 14, [11, 'satya']]
# 2964817734784

# %%
import copy
a=[12,13,14,[11,10]]
b=copy.deepcopy(a)
a[-1][-1]='satya'
print(a)
print(b) # in deep copy changes made in a by using indexing will not reflect on b
# Out:
# [12, 13, 14, [11, 'satya']]
# [12, 13, 14, [11, 'satya']]

# %%
del(a)
a #correctw away of deleting list or using del
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 del(a)
# ----> 2 a
#
# NameError: name 'a' is not defined

# %%
a.del() #wrong way deleting list
# Out:
#   Cell In[65], line 1
#     a.del()
#       ^
# SyntaxError: invalid syntax

# %%
a.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 a.copy()
#
# AttributeError: 'str' object has no attribute 'copy'

# %%
a.deepcopy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 2
#       1 a='teja'
# ----> 2 a.deepcopy()
#
# AttributeError: 'str' object has no attribute 'deepcopy'

# %%
a.clear()
a # clearin the list
# Out:
# []

# %%
b='teja'
c=9
b.clear()
c.clear() #we cannot use clear with string,int,etc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 3
#       1 b='teja'
#       2 c=9
# ----> 3 b.clear()
#       4 c.clear()
#
# AttributeError: 'str' object has no attribute 'clear'

# %%
a=[7,9,10,90,56,-1]

# %%
a.index(90) # finds the index of the element which the argument is passed
# Out:
# 3

# %%
a.sort()
a # sorts the elements in ascending order
# Out:
# [-1, 7, 9, 10, 56, 90]

# %%
b =[7,9,10,90,56,'teja'] #'<' not supported with alphas

# %%
b.sort()
b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 b.sort()
#       2 b
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
a.insert()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 a.insert()
#
# TypeError: insert expected 2 arguments, got 0

# %%
a=[7,9,10,90,56,-1]

# %%
a.insert(0,2) #inserts the value

# %%
a
# Out:
# [2, 7, 9, 10, 90, 56, -1]

# %%
a=[7,9,10,90,56,-1]
a.sort()
a
# Out:
# [-1, 7, 9, 10, 56, 90]

# %%
a=[7,9,10,90,56,-1]
a.sort(reverse = True)
a
# Out:
# [90, 56, 10, 9, 7, -1]

# %%
a=[7,9,10,90,56,-1]
sorted(a)
# Out:
# [-1, 7, 9, 10, 56, 90]

# %%
a=[7,9,10,90,56,-1]
sorted(a,reverse=True)
a
# Out:
# [7, 9, 10, 90, 56, -1]

# %%
a=[7,9,10,90,56]
a.pop()
a
#last element poped ou from list
# Out:
# [7, 9, 10, 90]

# %%
a=[7,9,10,90,56,-1,'teja']
a.reverse()
a 
#reverses the given list
# Out:
# ['teja', -1, 56, 90, 10, 9, 7]

# %% [markdown]
# # tuple(DAta Structure) -- for transactions cannot be changed(amount in bank account)

# %%
a=()
type(a)
# Out:
# tuple

# %%
b=(8,9,'teja',5) #heterogeneous

# %%
a=(2,7,5,9,8)

# %%
b #ordered
# Out:
# (8, 9, 'teja', 5)

# %%
a[0] #indexing
# Out:
# 2

# %%
a[0:4:2]#slicing
# Out:
# (2, 5)

# %%
a=(2,7,5,9,8,(4,3)) #nested

# %%
a[5][1]#nexted indexing
# Out:
# 3

# %%
a[0] = 5 #immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 a[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
a
# Out:
# (2, 7, 5, 9, 8, (4, 3))

# %%
a.count((4,3)) # counting number of elements
# Out:
# 1

# %%
a.count((3))
# Out:
# 0

# %%
a.index(5) #
# Out:
# 2

# %%
len(a)
# Out:
# 6

# %%
a=(2,7,5,9,8,(4,3))

# %%
min(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 min(a)
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
a=(2,7,5,9,8)

# %%
min(a) # for nested tupple min not working
# Out:
# 2

# %%
max(a) # for nested tupple max not working
# Out:
# 9

# %%
a = (2, 7, 5, 9, 8, (4, 3))

# %%
min(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 min(a)
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
sum(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sum(a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
del(a)

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# # set

# %%
a={1,4,6,'teja',9,7} #Heterogeneous

# %%
a #unordered
# Out:
# {1, 4, 6, 7, 9, 'teja'}

# %%
a[0] #no indexing and slicing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
a={1,4,6,'teja',9,7,(9 ,7)} #nested working

# %%
a #nested working
# Out:
# {(9, 7), 1, 4, 6, 7, 9, 'teja'}

# %%
a[1] = 5 #does not support indexing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 a[1] = 5
#
# TypeError: 'set' object does not support item assignment

# %%
b={4,7,9,5,6}
min(b)
# Out:
# 4

# %%
a={2,5,6,8,8,'teja'}

# %%
a.add(8) #takes only on element #mutable

# %%
a # doest not add duplicates
# Out:
# {2, 5, 6, 8, 'teja'}

# %%
a.update('swa') #it cann add more than 2 elements
a
# Out:
# {2, 5, 6, 8, 'a', 's', 'teja', 'w'}

# %%
a.pop() #poping(removing) elements randomlly
# Out:
# 8

# %%
a
# Out:
# {'a', 's'}

# %%
a.clear()
a # clearing all the elements
# Out:
# set()

# %%
a
# Out:
# set()

# %%
a={11,12,13,14}
a
# Out:
# {11, 12, 13, 14}

# %%
a.remove(11)
a # removes only element in the set
# Out:
# {12, 13, 14}

# %%
a={11,13,15,16}

# %%
a.remove(15) #removes elements

# %%
a
# Out:
# {11, 13, 16}

# %%
a.discard(11)

# %%
a
# Out:
# {13, 16}

# %%
a={11,12,13,14,20,78,9}

# %%
sorted(a)
# Out:
# [9, 11, 12, 13, 14, 20, 78]

# %%
a
# Out:
# {9, 11, 12, 13, 14, 20, 78}

# %%
a={11,12,13,14,20,78,9}

# %%
a.add(87)

# %%
a
# Out:
# {9, 11, 12, 13, 14, 20, 78, 87}

# %%
print(id(a))
# Out:
# 1904851428608

# %%
b='teja'
print(id(b))
b.replace('t','k')
# Out:
# 1906963374816
# 'keja'

# %%
id(b)
# Out:
# 1906963374816

# %%
a="manish"
print(id(a))
m=a.replace("m","p") #permannet change into new variable m
print(id(m))
#here string is immutable because adress of m and a are differ if the are same then string
#is mutable(changable)

#the changes are not made in in orginal string thats why its not mutable
# Out:
# 2964783253136
# 2964805757584
# 'panish'

# %%
print(a.replace("m","p")) #temporary change
id(a)
a #here orginal address the variable string is not stored its stored in copy location
# Out:
# panish
# 'manish'

# %%
a='DataStructure'
b=a.strip('Data')
b[-1:-10:-1]
# Out:
# 'erutcurtS'

# %%
a='DataStructure'
a.find('Structure')
b=a[4:]
a[:4]+b[-1:-10:-1]
# Out:
# 'DataerutcurtS'

# %% [markdown]
# ## union,intersection,&,diffrernce,

# %%
s1={1,2,3,4,5}
s2={12,13,3,4}
print(s1.union(s2))
print(s1|s2)
# Out:
# {1, 2, 3, 4, 5, 12, 13}
# {1, 2, 3, 4, 5, 12, 13}

# %%
s1={1,2,3,4,5}
s2={12,13,3,4}
print(s1.intersection(s2))
print(s1&s2)
# Out:
# {3, 4}
# {3, 4}

# %%
print(s1-s2)
print(s2-s1)
# Out:
# {1, 2, 5}
# {12, 13}

# %%
print(s1^s2)
print() #symentric difference
# Out:
# {1, 2, 5, 12, 13}

# %%
There are 2 Classrooms in a School classA consists of Karan,shirisha,krish,nagesh,
saurabh and classB consist of sakshi,shrikanth,sruthi,sristi .
Therew was a competition in the school and students Scored following marks in the competition.
In competition1 karan,shruthi,sakshi scored 3.4,3.5,4.7
an in competition 2 jayesh,shirisha,nagesh,saurabh scored 12,13,14,15

how many students in classA only participated in competition 2
how many students only participated in competition 1
how many students participated in both the competition who were not part of classA
total number of students in school
total number of students in competition
total number of students in the competition who were not from class A

# %%
classA ={'karan','shirisha','krish','nagesh','saurabh',}
classB ={'sakshi','shrikanth','shruthi','shristi'}
competition1={'karan','shruthi','sakshi'}
competition2={'jayesh','shirisha','nagesh','saurabh'}

# %%
#1
participated_only_in_compi2=competition2-competition1
participated_only_in_compi2
class_a_part_students_in_compi2=classA&participated_only_in_compi2
class_a_part_students_in_compi2
# Out:
# {'nagesh', 'saurabh', 'shirisha'}

# %%
# Out:
#   Cell In[3], line 1
#     [a={'teja'}]
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# ## dictionary

# %%
#a={key:value}
a={'manisha' : { 'nest' ,'tej' : ['paper','bags','clothes'] , [10,'bc']},
'satish' : ['cars','toys','bottles'],
'kailash' : ['food','cardboard'], 
'revati' : ['pens','paper','rubber'],
'sharvari' : ['pepsi','chips','90','5.5',9]}
# Out:
#   Cell In[124], line 2
#     a={'manisha' : { 'nest' ,'tej' : ['paper','bags','clothes'] , [10,'bc']},
#                                    ^
# SyntaxError: invalid syntax

# %%
a['sharvari'] : ['pepsi','chips','90','5.5'] #heterogeneous because we can add different types of data

# %%
a
# Out:
# {'manisha': ['paper', 'bags', 'clothes'],
#  'satish': ['cars', 'toys', 'bottles'],
#  'kailash': ['food', 'cardboard'],
#  'revati': ['pens', 'paper', 'rubber'],
#  'sharvari': ['pepsi', 'chips', '90', '5.5', 9]}

# %%
a['teja']=[10,'20','bgmi']
a['manisha'] = ['pen','book']
a #mutable(can be changed)
# Out:
# {'manisha': ['pen', 'book'],
#  'satish': ['cars', 'toys', 'bottles'],
#  'kailash': ['food', 'cardboard'],
#  'revati': ['pens', 'paper', 'rubber'],
#  'sharvari': ['pepsi', 'chips', '90', '5.5'],
#  'teja': [10, '20', 'bgmi']}

# %%
a.keys() #gives keys(names)
a.values() #gives values that are assigned with keys
a.items() #assins key and values in a tupple
# Out:
# dict_items([('manisha', ['pen', 'book']), ('satish', ['cars', 'toys', 'bottles']), ('kailash', ['food', 'cardboard']), ('revati', ['pens', 'paper', 'rubber']), ('sharvari', ['pepsi', 'chips', '90', '5.5']), ('teja', {10, 20, 'bgmi'})])

# %%
a['manisha'][1] 
a['teja'][0]
# orderd (can get values of manisha through indexing)
# Out:
# 10

# %%
#slicing is not possible dirrectly
a[0:1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 2
#       1 #slicing
# ----> 2 a[0:1]
#
# KeyError: slice(0, 1, None)

# %%
a['teja'][2][::1] #slicing is possible for keys(because they are sored in lists-->string) but not for whole dictionary
# Out:
# 'bgmi'

# %%
a=7/2
a
# Out:
# 3.5

# %%
type(a)
# Out:
# float

# %%
a={{'teja':1} : ['paper','bags','clothes']}
# in dictionary in values place any kind data can be inserted but in keys place ony the data that is hashable is only used(For example tuple())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a={{'teja':1} : ['paper','bags','clothes']}
#
# TypeError: unhashable type: 'dict'

# %%
a={('teja') : ['paper','bags','clothes']} #here we cann use tupple in values place because it is unhashable

# %%
a={1:2,3:5,9:20}
b={7:8,9:7}

# %%
a.keys() #giving names that are present in keys places
# Out:
# dict_keys([1, 3])

# %%
a.values() #giving names that are present in values places
# Out:
# dict_values([2, 5])

# %%
a.pop(1) # delets key value pair when we give name of key
# Out:
# 2

# %%
a
# Out:
# {3: 5}

# %%
b.popitem() #deletes the last index(positive indexing) or last key:value get deleting
# Out:
# (9, 7)

# %%
b
# Out:
# {7: 8}

# %%
del(a) #deletes dictionaru or anything if we given the name

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a={1:2,3:5}
b={7:8,9:7}

# %%
a.get(3) #gets the value if we given the key(key:value)
# Out:
# 5

# %%
a.update({2 : 'teja'})
a
# Out:
# {1: 'teja', 3: 5, 2: 'teja'}

# %%
a.fromkeys(a,b) #aasigns a key to b key:vale pairs when we use .fromkeys
# Out:
# {1: {7: 8, 9: 7}, 3: {7: 8, 9: 7}}

# %%
dict.fromkeys(a,b) #aasigns a key to b key:vale pairs when we use .fromkeys
# Out:
# {1: {7: 8, 9: 7}, 3: {7: 8, 9: 7}}

# %%
zip(a,b)

# %%
print(a)
print(list(zip(a,b))) #gives both keys with matching with indexes in tupple[] format
#print(tupple(zip(a,b))) #wrong
print(dict(zip(a,b))) #gives both keys with matching with indexes in dict{} format
print(set(zip(a,b))) #gives both keys with matching with indexes in set{} format
# Out:
# {1: 2, 3: 5}
# [(1, 7), (3, 9)]
# {1: 7, 3: 9}
# {(1, 7), (3, 9)}

# %%
{**a,**b} #adding two dictionaries into one(#a+b)
# Out:
# {1: 2, 3: 5, 7: 8, 9: 7}

# %%
a=[1,2,3]
b=[5,6,7,11,'p']
print(a+b)
print(id(a+b)) #thus storing in differ locations
id(a) #main address location
# Out:
# [1, 2, 3, 5, 6, 7, 11, 'p']
# 1384851845952
# 1384851883840

# %%
a='teja'

# %%
a.replace('t','k')
# Out:
# 'keja'

# %%
l=[1,2,3,4]

# %%
l[0] = 3
l
# Out:
# [3, 2, 3, 4]

# %%
t={1,2,3,4,5}
type(t)
# Out:
# set

# %%
t.update('6')
t
# Out:
# {1, 2, 3, 4, 5, '6'}

# %% [markdown]
# ## input class

# %%
a=input('Give your value')
a
# Out:
# Give your value hello
# 'hello'

# %%
a=int(input('Give your value'))
a
# Out:
# Give your value 45
# 45

# %%
a=list(input('Give your value'))
a
# Out:
# Give your value 12,13,14
# ['1', '2', ',', '1', '3', ',', '1', '4']

# %%
a=eval(input('Give your input'))
a
# Out:
# Give your input [12,13,14]
# [12, 13, 14]

# %%
a=10,10,20,30,30
a[0]
# Out:
# 10

# %% [markdown]
# ## (doubts)Quiz 2 lists and tuples(doubts)

# %%
list1=list()
type(list1)
# Out:
# list

# %%
tuple1=(5,1,7,6,2)
tuple1.pop(2)
print(tuple1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 tuple1=(5,1,7,6,2)
# ----> 2 tuple1.pop(2)
#       3 print(tuple1)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
tuple('abc',)
# Out:
# ('a', 'b', 'c')

# %%
tuple1=('abc')
tuple1
# Out:
# 'abc'

# %%
x=[1,2]
y=[3,4]
x.append([3,4])
x.extend([5,6])
x
# Out:
# [1, 2, [3, 4], 5, 6]

# %%
a=input()
len(a)
# Out:
#  teja
# 4
